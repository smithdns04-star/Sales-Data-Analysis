# %% [markdown]
# <a href="https://colab.research.google.com/github/smithdns04-star/Sales-Data-Analysis/blob/main/Supermarket_Sales_Data_Analytics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

data = pd.read_csv(url)

data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data = data.drop_duplicates()

data.shape
# Out:
# (243, 7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='day', data=data)
plt.title('Number of Customers by Day')
plt.show()

# %%
data['day'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6,6)
)

plt.title("Customer Distribution by Day")
plt.ylabel("")
plt.show()

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
data = pd.read_csv(url)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(data['total_bill'], bins=10)

plt.title("Distribution of Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.boxplot(x=data['total_bill'])

plt.title("Box Plot of Total Bill")
plt.xlabel("Total Bill")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation = data.select_dtypes(include=['number']).corr()

plt.figure(figsize=(6,4))
sns.heatmap(correlation, annot=True, cmap='Blues')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Final Insights
#
# 1. The dataset contains restaurant billing information.
# 2. There are no missing values in the dataset.
# 3. Duplicate records were checked and removed.
# 4. The bar chart shows customer visits on different days.
# 5. The pie chart shows the percentage of customers by day.
# 6. The histogram shows the distribution of total bill amounts.
# 7. The box plot identifies outliers in the total bill.
# 8. The heatmap shows the correlation between numerical columns.
# 9. The dataset is clean and suitable for data analysis.
# 10. Data visualization makes it easier to understand customer spending patterns.

# %% [markdown]
# # Conclusion
#
# This project analyzed the restaurant billing dataset using Python in Google Colab. The dataset was cleaned by checking for missing values and duplicate records. Various charts such as a bar chart, pie chart, histogram, box plot, and heatmap were created to understand customer behavior and spending patterns. The analysis showed that data visualization helps identify trends and supports better business decision-making. This project improved my understanding of data analytics using Python.
